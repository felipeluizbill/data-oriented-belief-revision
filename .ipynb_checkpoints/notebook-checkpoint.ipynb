# %%
import pandas as pd;
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

# %%
EXP_A = ["regras por objetivo = 3.csv" , "regras por objetivo = 4.csv" , "regras por objetivo = 5.csv"]
EXP_B = [ "objetivos = 100 crenças = 500.csv" , "objetivos = 100 crenças = 1000.csv", "objetivos = 50 crenças = 1000.csv"]
EXP_C = [ "fator de dinâmica = 0.csv", "fator de dinâmica = 0.1.csv" , "fator de dinâmica = 0.2.csv"]

persistencia = [ "Persistente" , "Reminiscente"  , "Obliterante"];
PERSISTENTE = 0 ; REMINISCENTE = 1 ; OBLITERANTE = 2;

raciocinio = ["SOAR" , "BDI" , "BBGP"];
SOAR = 0 ; BDI = 1 ; BBGP = 2;

relevancia = ["Customizado" , "Linha base"]
CUSTOMIZADO = 0 ; LINHA_BASE = 1;

metrica = ["cpu" , "memoria"];
metricaNormalizada = ["cpuNormal" , "memoriaNormal"];
CPU = 0 ; MEM = 1

# %%
def normalizar(data):
    df_min_max_scaled = data.copy()
    column = 'cpu';
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min()) 
    data['cpuNormal'] =  df_min_max_scaled[column];
    column = 'memoria';
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min()) 
    data['memoriaNormal'] =  df_min_max_scaled[column];
    return data;

# %%
def ordenarDataFrame(DADOS):
    multi_tuples = [( ' Persistente ', 'Linha base '),( ' Persistente ',  'Customizado '),(' Reminiscente ', 'Linha base '),(' Reminiscente ',  'Customizado '),( ' Obliterante ', 'Linha base '),( ' Obliterante ',  'Customizado ')]
    multi_cols = pd.MultiIndex.from_tuples(multi_tuples, names=['Persistência','Relevância'])
    return pd.DataFrame(DADOS, columns=multi_cols)

# %%
def obterDadosNormalizados(PLANILHA , RACIOCINIO , METRICA):
    dados = pd.read_csv(PLANILHA , sep =";", decimal =",")
    dados = normalizar(dados);
    dados = dados.loc[(dados['raciocinio'].str.contains(raciocinio[RACIOCINIO]))]
    dados = dados.groupby(['persistencia' , 'relevancia'])[metricaNormalizada[METRICA]]
    dados = dados.describe()[['mean' , 'std' , 'min' , '25%', '50%', '75%','max']];
    transposta = dados.T
    ordenada = ordenarDataFrame(transposta)
    return pd.DataFrame(ordenada)

# %%
def obterResultadosNormalizadosConcatenados(EXPERIMENTO , RACIOCINIO, METRICA):
    cenario0 = obterDadosNormalizados(EXP_A[0] , RACIOCINIO, METRICA)
    cenario0 = cenario0.T
    cenario1 = obterDadosNormalizados(EXP_A[1] , RACIOCINIO, METRICA)
    cenario1 = cenario1.T
    cenario2 = obterDadosNormalizados(EXP_A[2] , RACIOCINIO, METRICA)
    cenario2 = cenario2.T
    frames = [cenario0 , cenario1, cenario2]
    return pd.concat(frames , keys=[EXPERIMENTO[0].replace(".csv",""),EXPERIMENTO[1].replace(".csv",""),EXPERIMENTO[2].replace(".csv","")])

obterResultadosNormalizadosConcatenados(EXP_B , BBGP, CPU)
# Out:
#                                                                 mean  \
#                                Persistência   Relevância
# objetivos = 100 crenças = 500   Persistente   Linha base    0.037886
#                                               Customizado   0.037886
#                                 Reminiscente  Linha base    0.252918
#                                               Customizado   0.339095
#                                 Obliterante   Linha base    0.320032
#                                               Customizado   0.350685
# objetivos = 100 crenças = 1000  Persistente   Linha base    0.063910
#                                               Customizado   0.063910
#                                 Reminiscente  Linha base    0.296143
#                                               Customizado   0.332970
#                                 Obliterante   Linha base    0.254293
#                                               Customizado   0.302791
# ...

# %%
def exportarTabelaNormalizadaLatex(EXPERIMENTO , RACIOCINIO , METRICA):
    dados = obterResultadosNormalizadosConcatenados(EXPERIMENTO , RACIOCINIO , METRICA)
    dados = dados.round(3);
    #display(dados)
    latex = dados.to_latex()
    latex = latex.replace("mean" , "$\mu$")
    latex = latex.replace("std" , "$\sigma$")
    latex = latex.replace("\\begin{tabular}{lllrrrrrrr}","\\begin{table}[htb] \n \\begin{tabular}{lllrrrrrrr}")
    legenda = "Distribuição normalizada da eficiência de " + metrica[METRICA] + " com o modelo " + raciocinio[RACIOCINIO] 
    legenda = legenda.replace("cpu","processamento")
    legenda = legenda.replace("memoria","memória")
    nomeTabela = "DistribuicaoEficiencia_"+metrica[METRICA]+"_"+raciocinio[RACIOCINIO]+"_Experimento_C"
    latex = latex.replace("\\end{tabular}" , "\\end{tabular} \n \\caption{\label{tab:"+nomeTabela+"} " + legenda + " } \\fonte{Autoria própria.} \n \\end{table}")     
    print(latex)

# %%
props = dict(linestyle='-', linewidth=2, color='black')


lab = ['Persistente\nLinha base' , 'Persistente\nCustomizado', 'Reminiscente\nLinha base' , 'Reminiscente\nCustomizado' , 'Obliterante\nLinha base' , 'Obliterante\nCustomizado']

def plotarGrafico(EXPERIMENTO, RACIOCINIO , METRICA):
    fig, ax = plt.subplots(1, len(EXPERIMENTO), sharex=False, sharey=True)
    for i, x in enumerate(EXPERIMENTO):
        dados = obterDadosNormalizados(x , RACIOCINIO , METRICA)
        dados.plot.box(by='persistencia', title=x.replace(".csv",""), boxprops=props, grid=True , figsize=(12,4), ax=ax[i])
        ax[i].set_xticks([1,2,3,4,5,6])
        ax[i].set_xticklabels(labels = lab, rotation="vertical")
        ax[i].set_ylim(0,1)
    plt.tight_layout()
    
    nomeFigura = raciocinio[RACIOCINIO]+ "_" + metrica[METRICA]
    plt.savefig('figures\\dinamica' + nomeFigura+ '.pdf')
    

    
def plotarGraficosPorExperimento(EXPERIMENTO):
    plotarGrafico(EXPERIMENTO , SOAR , CPU)
    plotarGrafico(EXPERIMENTO , BDI , CPU)
    plotarGrafico(EXPERIMENTO , BBGP , CPU)
    
    plotarGrafico(EXPERIMENTO , BDI , MEM)
    plotarGrafico(EXPERIMENTO , SOAR , MEM)
    plotarGrafico(EXPERIMENTO , BBGP , MEM)

plotarGraficosPorExperimento(EXP_C)

# %%
def obterDadosPorRaciocinio(PLANILHA , RACIOCINIO):
    dados = pd.read_csv(PLANILHA , sep =";", decimal =",")
    return dados.loc[(dados['raciocinio'].str.contains(raciocinio[RACIOCINIO]))] 
    
def obterMedidas(DADOS , PROPRIEDADE):
    valores = DADOS.groupby(['persistencia' , 'relevancia'])[PROPRIEDADE].describe()[['mean' , 'std' , 'min' , '25%', '50%', '75%', 'max']]
    transposta = valores.T
    ordenada = ordenarDataFrame(transposta)
    return pd.DataFrame(ordenada)
    
COMPARACOES = 'comparacoes' ; MOVIMENTACOES = "movimentacoes" ; CRENCAS_ATIVAS = "crencasAtivas" ; UTILIDADE = "utilidade";    
    
def obterDadosAgrupados(PLANILHA , RACIOCINIO):
    dados = pd.read_csv(PLANILHA , sep =";", decimal =",")
    dados = dados.loc[(dados['raciocinio'].str.contains(raciocinio[RACIOCINIO]))]
    comparacoes = obterMedidas(dados , COMPARACOES)
    comparacoes = comparacoes.T
    crencasAtivas = obterMedidas(dados , CRENCAS_ATIVAS)
    crencasAtivas = crencasAtivas.T
    movimentacoes = obterMedidas(dados , MOVIMENTACOES)
    movimentacoes = movimentacoes.T
    utilidade = obterMedidas(dados , UTILIDADE)
    utilidade = utilidade.T
    frames = [comparacoes , crencasAtivas , movimentacoes, utilidade]
    return pd.concat(frames , keys=["Comparações" , "Crenças ativas" , "Movimentações" , "Utilidade"])

# %%
def exportarTabelaPlenaLatex(EXPERIMENTO , RACIOCINIO, NOME_EXPERIMENTO):
    for i, x in enumerate(EXPERIMENTO):
        dados = obterDadosAgrupados(x , RACIOCINIO)
        dados = dados.round(2);
        latex = dados.to_latex()
        latex = latex.replace("mean" , "$\mu$")
        latex = latex.replace("std" , "$\sigma$")
        latex = latex.replace("Comparações" , "Comp.")
        latex = latex.replace("Crenças ativas" , "Crenças")
        latex = latex.replace("Movimentações" , "Mov.")
        latex = latex.replace("Utilidade" , "Util.")
        
        latex = latex.replace("Persistência" , "Persist.")
        latex = latex.replace("Relevância" , "Relev.")
        latex = latex.replace("Linha base" , "Base")
        latex = latex.replace("Customizado" , "Cust.")
        latex = latex.replace("Persistente" , "Pers.")
        latex = latex.replace("Reminiscente" , "Remi.")
        latex = latex.replace("Obliterante" , "Obli.")
        
        
        latex = latex.replace("begin{tabular}{lllrrrrrrr}","begin{table}[htb] \n \\begin{tabular}{lllrrrrrrr}")
        legenda = "Distribuição de comparações, movimentações, crenças ativas e utilidade alcançada. \n Modelo: " + raciocinio[RACIOCINIO] + "; experimento : " + NOME_EXPERIMENTO + "; cenário: " + x.replace(".csv","")
        nomeTabela = "Observacoes_"+NOME_EXPERIMENTO.replace(" ","")+str(i)+"_"+raciocinio[RACIOCINIO]
        latex = latex.replace("\\end{tabular}" , "\\end{tabular} \n \\caption{\label{tab:"+nomeTabela+"} " + legenda + " } \\fonte{Autoria própria.} \n \\end{table}")     
        print(latex)
        

exportarTabelaPlenaLatex(EXP_A , SOAR , "Experimento A")
# Out:
# \begin{table}[htb]
#  \begin{tabular}{lllrrrrrrr}
# \toprule
#           &               &              &      $\mu$ &       $\sigma$ &       min &       25\% &        50\% &        75\% &        max \\
# {} & Persist. & Relev. &           &           &           &           &            &            &            \\
# \midrule
# Comp. &  Pers.  & Base  &  99797.36 &   7551.93 &  78526.27 &  94711.09 &  100396.81 &  103390.58 &  121076.35 \\
#           &               & Cust.  &  99797.36 &   7551.93 &  78526.27 &  94711.09 &  100396.81 &  103390.58 &  121076.35 \\
#           &  Remi.  & Base  &  58967.77 &  11786.34 &  17810.62 &  51701.84 &   60132.33 &   67210.02 &   89227.04 \\
#           &               & Cust.  &  59301.86 &  11818.63 &  18630.25 &  51843.90 &   59993.74 &   67039.24 &   85140.85 \\
#           &  Obli.  & Base  &   5117.93 &    359.55 &   4325.58 &   4913.11 &    5118.33 &    5322.15 &    6410.17 \\
# ...

# %%
from scipy.stats import kruskal

def kruskalTestCpu(memoryStrategyIndex, engineIndex, data):
    dist1 = select(memoryStrategyIndex , engineIndex, 0 , data)[efficiencyProperties[CPU]]
    dist2 = select(memoryStrategyIndex , engineIndex, engineIndex+1 , data)[efficiencyProperties[CPU]]
    stat , p = kruskal(dist1 , dist2)
    print('stat=%.3f, p=%.3f' % (stat, p))
    if p > 0.05:
        return False;
    else:
        return True

# %%
data = readFromCsvScaled(DYNAMICS_SCENARIO[1]);

kruskalTestCpu(FORGETTING, SOAR, data);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-ceeadc1a58e8> in <module>
# ----> 1 data = readFromCsvScaled(DYNAMICS_SCENARIO[1]);
#       2
#       3 kruskalTestCpu(FORGETTING, SOAR, data);
#
# NameError: name 'readFromCsvScaled' is not defined
