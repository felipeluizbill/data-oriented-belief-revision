# %%
import pandas as pd;
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("dynamics = 0.2.csv" , sep =";", decimal =",")

# %%
df_min_max_scaled = data.copy()
column = 'cpuEfficiency';
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min()) 

data['cpuScaled'] = df_min_max_scaled[column];

display(data)
# Out:
#                      relevanceModel        memoryStrategy        engine  \
# 0     BBGPIntegratedRelevanceModel               DEFAULT    BBGPEngine
# 1     BBGPIntegratedRelevanceModel               DEFAULT    BBGPEngine
# 2     BBGPIntegratedRelevanceModel               DEFAULT    BBGPEngine
# 3     BBGPIntegratedRelevanceModel               DEFAULT    BBGPEngine
# 4     BBGPIntegratedRelevanceModel               DEFAULT    BBGPEngine
# ...                             ...                   ...           ...
# 1147  SOARIntegratedRelevanceModel    STORING_RETRIEVING    SOAREngine
# 1148  SOARIntegratedRelevanceModel    STORING_RETRIEVING    SOAREngine
# 1149  SOARIntegratedRelevanceModel    STORING_RETRIEVING    SOAREngine
# 1150  SOARIntegratedRelevanceModel    STORING_RETRIEVING    SOAREngine
# 1151  SOARIntegratedRelevanceModel    STORING_RETRIEVING    SOAREngine
#
#      storing retrieving oblivion  comparisions  activeBeliefs        pages  \
# 0       0.4        0.2      0.8      166716.50      238.57726      0.00000
# 1       0.8        0.4      0.8      166716.50      238.57726      0.00000
# 2       0.8        0.8      0.8      166716.50      238.57726      0.00000
# 3       0.6        0.4      0.2      166716.50      238.57726      0.00000
# 4       0.6        0.6      0.4      166716.50      238.57726      0.00000
# ...      ...        ...      ...           ...            ...          ...
# 1147    0.2        0.8      0.8      187136.23       52.43125    370.82724
# 1148    0.2        0.6      0.8      179675.61       49.86175    372.72775
# 1149    0.6        0.4      0.8      184740.67       25.82875  19339.93000
# 1150    0.2        0.4      0.6      180997.94       51.89050    376.33850
# 1151    0.2        0.2      0.8      179826.75       45.09225    425.45874
#
#       utilitySum  cpuEfficiency  memEfficiency  cpuScaled
# 0      26.050825       0.109192       0.015626   0.039311
# 1      26.019821       0.109062       0.015607   0.039259
# 2      25.858519       0.108386       0.015510   0.038986
# 3      26.034573       0.109124       0.015616   0.039283
# 4      26.345545       0.110428       0.015803   0.039808
# ...          ...            ...            ...        ...
# 1147   21.753658       0.112023       0.003078   0.040450
# 1148   21.700111       0.117505       0.003195   0.042657
# 1149    7.630465       0.079765       0.000545   0.027465
# 1150   21.465557       0.111691       0.003137   0.040317
# 1151   23.557524       0.141056       0.003455   0.052137
#
# [1152 rows x 13 columns]

# %%
import pandas as pd
from sklearn import preprocessing

x = data.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = data.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8c71491730d8> in <module>
#       4 x = data.values #returns a numpy array
#       5 min_max_scaler = preprocessing.MinMaxScaler()
# ----> 6 x_scaled = min_max_scaler.fit_transform(x)
#       7 df = data.DataFrame(x_scaled)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     334         # Reset internal state before fitting
#     335         self._reset()
# --> 336         return self.partial_fit(X, y)
#     337
#     338     def partial_fit(self, X, y=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     367
#     368         first_pass = not hasattr(self, 'n_samples_seen_')
# --> 369         X = self._validate_data(X, reset=first_pass,
#     370                                 estimator=self, dtype=FLOAT_DTYPES,
#     371                                 force_all_finite="allow-nan")
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'BBGPIntegratedRelevanceModel '
